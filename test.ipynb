# %%
import pandas as pd
import numpy as np
import plotly.express as px

df_raw=pd.read_csv("data/raw/dataset/consommation-annuelle-d-electricite-et-gaz-par-commune.csv", sep=";")
print(df_raw.info())
# Out:
# C:\Users\alexp\AppData\Local\Temp\ipykernel_2200\2949404573.py:5: DtypeWarning: Columns (3,5,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_raw=pd.read_csv("data/raw/dataset/consommation-annuelle-d-electricite-et-gaz-par-commune.csv", sep=";")
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3405751 entries, 0 to 3405750
# Data columns (total 47 columns):
#  #   Column                                                                      Dtype
# ---  ------                                                                      -----
#  0   OPERATEUR                                                                   object
#  1   FILIERE                                                                     object
#  2   Année                                                                       int64
#  3   Code Commune                                                                object
#  4   Nom Commune                                                                 object
#  5   Code EPCI                                                                   object
#  6   Nom EPCI                                                                    object
#  7   Type EPCI                                                                   object
#  8   Code Département                                                            object
#  9   Nom Département                                                             object
#  10  Code Région                                                                 int64
#  11  Nom Région                                                                  object
#  12  CODE CATEGORIE CONSOMMATION                                                 object
#  13  CODE GRAND SECTEUR                                                          object
#  14  CODE SECTEUR NAF2                                                           float64
#  15  Nb sites                                                                    float64
#  16  Conso totale (MWh)                                                          float64
#  17  Conso moyenne (MWh)                                                         float64
#  18  Nombre de mailles secretisées                                               float64
#  19  Part thermosensible (%)                                                     float64
#  20  Conso totale à usages thermosensibles (MWh)                                 float64
#  21  Conso totale à usages non thermosensibles (MWh)                             float64
#  22  Thermosensibilité totale (kWh DJU)                                          float64
#  23  Conso totale corrigée de l'aléa climatique à usages thermosensibles (MWh)   float64
#  24  Conso moyenne à usages thermosensibles (MWh)                                float64
#  25  Conso moyenne à usages non thermosensibles (MWh)                            float64
#  26  Thermosensibilité moyenne (kWh DJU)                                         float64
#  27  Conso moyenne corrigée de l'aléa climatique à usages thermosensibles (MWh)  float64
#  28  DJU à TR                                                                    float64
#  29  DJU à TN                                                                    float64
#  30  Nombre d'habitants                                                          float64
#  31  Taux de logements collectifs                                                float64
#  32  Taux de résidences principales                                              float64
#  33  Superficie des logements <30 m2                                             float64
#  34  Superficie des logements 30 à 40 m2                                         float64
#  35  Superficie des logements 40 à 60 m2                                         float64
#  36  Superficie des logements 60 à 80 m2                                         float64
#  37  Superficie des logements 80 à 100 m2                                        float64
#  38  Superficie des logements >100 m2                                            float64
#  39  Résidences principales avant 1919                                           float64
#  40  Résidences principales de 1919 à 1945                                       float64
#  41  Résidences principales de 1946 à 1970                                       float64
#  42  Résidences principales de 1971 à 1990                                       float64
#  43  Résidences principales de 1991 à 2005                                       float64
#  44  Résidences principales de 2006 à 2018                                       float64
#  45  Résidences principales après 2019                                           float64
#  46  Taux de chauffage électrique                                                float64
# dtypes: float64(33), int64(2), object(12)
# memory usage: 1.2+ GB
# None

# %%
print(df_raw["Année"].value_counts())
print(df_raw.columns)
# Out:
# Année
# 2023    384372
# 2022    384343
# 2024    384108
# 2021    383722
# 2020    378575
# 2019    373799
# 2018    368956
# 2017    111605
# 2016    111406
# 2015    111344
# 2014    105485
# 2013    105235
# 2012    102521
# 2011    100280
# Name: count, dtype: int64
# Index(['OPERATEUR', 'FILIERE', 'Année', 'Code Commune', 'Nom Commune',
#        'Code EPCI', 'Nom EPCI', 'Type EPCI', 'Code Département',
#        'Nom Département', 'Code Région', 'Nom Région',
#        'CODE CATEGORIE CONSOMMATION', 'CODE GRAND SECTEUR',
#        'CODE SECTEUR NAF2', 'Nb sites', 'Conso totale (MWh)',
#        'Conso moyenne (MWh)', 'Nombre de mailles secretisées',
#        'Part thermosensible (%)',
#        'Conso totale à usages thermosensibles (MWh)',
#        'Conso totale à usages non thermosensibles (MWh)',
#        'Thermosensibilité totale (kWh DJU)',
#        'Conso totale corrigée de l'aléa climatique à usages thermosensibles (MWh)',
#        'Conso moyenne à usages thermosensibles (MWh)',
#        'Conso moyenne à usages non thermosensibles (MWh)',
#        'Thermosensibilité moyenne (kWh DJU)',
#        'Conso moyenne corrigée de l'aléa climatique à usages thermosensibles (MWh)',
#        'DJU à TR', 'DJU à TN', 'Nombre d'habitants',
#        'Taux de logements collectifs', 'Taux de résidences principales',
#        'Superficie des logements <30 m2',
#        'Superficie des logements 30 à 40 m2',
#        'Superficie des logements 40 à 60 m2',
#        'Superficie des logements 60 à 80 m2',
#        'Superficie des logements 80 à 100 m2',
#        'Superficie des logements >100 m2', 'Résidences principales avant 1919',
#        'Résidences principales de 1919 à 1945',
#        'Résidences principales de 1946 à 1970',
#        'Résidences principales de 1971 à 1990',
#        'Résidences principales de 1991 à 2005',
#        'Résidences principales de 2006 à 2018',
#        'Résidences principales après 2019', 'Taux de chauffage électrique'],
#       dtype='object')

# %%
cols1 = df_raw.loc[:,"OPERATEUR" : "Nom Commune"].columns
cols2 = df_raw.loc[:,"Code Département" : "CODE GRAND SECTEUR"].columns
cols3 = df_raw.loc[:,"Conso totale (MWh)": "Conso moyenne (MWh)"].columns
cols4 = df_raw.loc[:,"Nombre d'habitants":"Superficie des logements >100 m2"].columns
cols5 = ["Taux de chauffage électrique"]

#cols = selected_cols = (
#    cols1.tolist()
#    + cols2.tolist()
#    + cols3.tolist()
#    + cols4.tolist()
#    + cols5
#)

df = df_raw.loc[:,cols1.tolist()+ cols2.tolist()+ cols3.tolist()+ cols4.tolist()+ cols5]
print(df.info())
df.to_csv("data/cleaned/cleanedDataset.csv")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3405751 entries, 0 to 3405750
# Data columns (total 23 columns):
#  #   Column                                Dtype
# ---  ------                                -----
#  0   OPERATEUR                             object
#  1   FILIERE                               object
#  2   Année                                 int64
#  3   Code Commune                          object
#  4   Nom Commune                           object
#  5   Code Département                      object
#  6   Nom Département                       object
#  7   Code Région                           int64
#  8   Nom Région                            object
#  9   CODE CATEGORIE CONSOMMATION           object
#  10  CODE GRAND SECTEUR                    object
#  11  Conso totale (MWh)                    float64
#  12  Conso moyenne (MWh)                   float64
#  13  Nombre d'habitants                    float64
#  14  Taux de logements collectifs          float64
#  15  Taux de résidences principales        float64
#  16  Superficie des logements <30 m2       float64
#  17  Superficie des logements 30 à 40 m2   float64
#  18  Superficie des logements 40 à 60 m2   float64
#  19  Superficie des logements 60 à 80 m2   float64
#  20  Superficie des logements 80 à 100 m2  float64
#  21  Superficie des logements >100 m2      float64
#  22  Taux de chauffage électrique          float64
# dtypes: float64(12), int64(2), object(9)
# memory usage: 597.6+ MB
# None

# %%
conso_moy_per_region ={}
for i,region in enumerate(df["Code Région"].sort_values().unique()) : 
    df_region = df[df["Code Région"]==region]
    mean_conso = df_region["Conso moyenne (MWh)"].mean()
    conso_moy_per_region[(int)(region)] = (float)(mean_conso)

print(conso_moy_per_region)
# Out:
# {1: 171.23301120628471, 2: 182.46435574529002, 3: 217.8879687368006, 4: 255.23559237421685, 6: 126.35992532884634, 11: 1268.936751921546, 24: 594.9610492593451, 27: 518.1056517535516, 28: 1431.9635263773182, 32: 1572.5785204303152, 44: 1268.0557718850603, 52: 825.6028541636061, 53: 711.2303260229701, 75: 485.7867741490912, 76: 349.5172071938808, 84: 904.6782910351809, 93: 1519.2209222792103, 94: 69.75695178503368}
